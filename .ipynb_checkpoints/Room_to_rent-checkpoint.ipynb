# %%
# Dependencies
import numpy as np
import pandas as pd
from geopy.distance import geodesic
import numpy as np

# %%
# Import the room rent data into a Pandas DataFrame
rent_pd = pd.read_csv("AB_NYC_2019.csv")

# Preview the data
rent_pd.head()
# Out:
# /Users/jayachandranjohn/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (6,7,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902   -73.9419
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights number_of_reviews last_review  \
# 0     Private room    149               1                 9  2018-10-19
# 1  Entire home/apt    225               1                45  2019-05-21
# 2     Private room    150               3                 0         NaN
# 3  Entire home/apt     89               1               270  2019-07-05
# 4  Entire home/apt     80              10                 9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6             365.0
# 1               0.38                               2             355.0
# 2                NaN                               1             365.0
# 3               4.64                               1             194.0
# 4               0.10                               1               0.0

# %%
# Convert Latitude and Longitude to float
rent_pd['latitude'] = pd.to_numeric(rent_pd['latitude'],errors='coerce')
rent_pd['longitude'] = pd.to_numeric(rent_pd['longitude'],errors='coerce')
#Drop NA data for latitude, longitude and name
rent_pd = rent_pd.dropna(subset=['latitude', 'longitude', 'name'])
rent_pd = rent_pd.fillna({'last_review':"No Reviews", 'reviews_per_month':0}, inplace=True)
#Create new column
rent_pd.insert(8, "Distance", np.nan)

rent_pd = rent_pd.reset_index(drop=True)
rent_pd.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#    Distance        room_type  price  minimum_nights number_of_reviews  \
# 0       NaN     Private room    149               1                 9
# 1       NaN  Entire home/apt    225               1                45
# 2       NaN     Private room    150               3                 0
# 3       NaN  Entire home/apt     89               1               270
# 4       NaN  Entire home/apt     80              10                 9
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2018-10-19               0.21                               6
# 1  2019-05-21               0.38                               2
# 2  No Reviews               0.00                               1
# 3  2019-07-05               4.64                               1
# 4  2018-11-19               0.10                               1
#
#    availability_365
# 0             365.0
# 1             355.0
# 2             365.0
# 3             194.0
# 4               0.0

# %%
print("Search room for rent")
lat1 = float(input("Input Latitude: "))
lon1 = float(input("Input Longitude: "))
query = input("Input Query: ")
dist1 = float(input("Input distance in miles: "))
# Out:
# Search room for rent
# Input Latitude: 40.64
# Input Longitude: -73.9
# Input Query: two bedroom
# Input distance in miles: 10

# %%
#Function to find distance in between two (lat, lon) locations 
def dist2(lat1, lon1, lat2, lon2):
    return geodesic((lat1, lon1), (lat2, lon2)).miles

# Fill Distance column with calculated distance in miles
rent_pd['Distance'] = np.vectorize(dist2)(lat1, lon1, rent_pd['latitude'], rent_pd['longitude'])

#Filter rent panda dataframe based on distance and query
if dist1:
    rent_pd = rent_pd.loc[rent_pd["Distance"] <= dist1]
if query:
    rent_pd = rent_pd[rent_pd["name"].str.contains(query)]

rent_pd.head()
# Out:
#            id                                        name   host_id host_name  \
# 1755   794425                        Brooklyn two bedroom   4185135     David
# 4096  2635794  room in a two bedroom apt, whole apartment  13496782    Nicole
# 4927  3533604          Private Room in a two bedroom apt.   9510645     Rylan
# 5250  3799598          ★Unique two bedroom on 2nd Avenue★   7558452       Zev
# 5318  3840286                   Modern, sunny two bedroom   1482208   Allison
#
#      neighbourhood_group    neighbourhood  latitude  longitude  Distance  \
# 1755            Brooklyn  Windsor Terrace  40.65954  -73.97805  4.317820
# 4096            Brooklyn     Williamsburg  40.70719  -73.96407  5.729272
# 4927            Brooklyn         Bushwick  40.70399  -73.92813  4.656188
# 5250           Manhattan     East Village  40.72328  -73.98926  7.416671
# 5318            Brooklyn     Williamsburg  40.71159  -73.94043  5.377105
#
#             room_type  price  minimum_nights number_of_reviews last_review  \
# 1755  Entire home/apt    199             265                20  2018-07-27
# 4096  Entire home/apt    200               1                 2  2016-12-12
# 4927     Private room     96               1               332  2019-07-06
# 5250  Entire home/apt    260               1               299  2019-06-23
# 5318  Entire home/apt    246               2                25  2019-03-31
#
#       reviews_per_month  calculated_host_listings_count  availability_365
# 1755               0.32                               2              90.0
# 4096               0.06                               1               0.0
# 4927               5.57                               2             355.0
# 5250               5.04                               2             232.0
# 5318               0.54                               2               0.0

# %%
#Sort Filtered Data based on 
filter_rent_pd = rent_pd.sort_values(by="Distance")
filter_rent_pd.set_index(['name'], inplace=True)
filter_rent_pd.head()
# Out:
#                                                          id    host_id  \
# name
# Private room in a clean two bedroom apartment      35539005  266117120
# Beautiful two bedroom apartment with backyard      14824875   68082479
# Private bedroom in two bedroom apartment Brooklyn  24645220  115258603
# Sunny, quiet, and cool bedroom in a two bedroom.   36446514  274025920
# Sweet two bedroom in Crown Heights Bk              15819242   41191579
#
#                                                   host_name  \
# name
# Private room in a clean two bedroom apartment       Adedayo
# Beautiful two bedroom apartment with backyard      Sunshine
# Private bedroom in two bedroom apartment Brooklyn      Toun
# Sunny, quiet, and cool bedroom in a two bedroom.     Oliver
# Sweet two bedroom in Crown Heights Bk                 Maura
#
#                                                   neighbourhood_group  \
# name
# Private room in a clean two bedroom apartment                Brooklyn
# Beautiful two bedroom apartment with backyard                Brooklyn
# Private bedroom in two bedroom apartment Brooklyn            Brooklyn
# Sunny, quiet, and cool bedroom in a two bedroom.             Brooklyn
# Sweet two bedroom in Crown Heights Bk                        Brooklyn
#
#                                                    neighbourhood  latitude  \
# name
# Private room in a clean two bedroom apartment        Brownsville  40.65944
# Beautiful two bedroom apartment with backyard      East New York  40.67350
# Private bedroom in two bedroom apartment Brooklyn  Crown Heights  40.67254
# Sunny, quiet, and cool bedroom in a two bedroom.   Crown Heights  40.66921
# Sweet two bedroom in Crown Heights Bk              Crown Heights  40.67034
#
#                                                    longitude  Distance  \
# name
# Private room in a clean two bedroom apartment      -73.91489  1.552965
# Beautiful two bedroom apartment with backyard      -73.89635  2.319497
# Private bedroom in two bedroom apartment Brooklyn  -73.91686  2.413794
# Sunny, quiet, and cool bedroom in a two bedroom.   -73.93521  2.736071
# Sweet two bedroom in Crown Heights Bk              -73.93902  2.930433
#
#                                                          room_type  price  \
# name
# Private room in a clean two bedroom apartment         Private room     55
# Beautiful two bedroom apartment with backyard      Entire home/apt    135
# Private bedroom in two bedroom apartment Brooklyn     Private room     62
# Sunny, quiet, and cool bedroom in a two bedroom.      Private room     59
# Sweet two bedroom in Crown Heights Bk              Entire home/apt     87
#
#                                                    minimum_nights  \
# name
# Private room in a clean two bedroom apartment                   1
# Beautiful two bedroom apartment with backyard                  30
# Private bedroom in two bedroom apartment Brooklyn               2
# Sunny, quiet, and cool bedroom in a two bedroom.                2
# Sweet two bedroom in Crown Heights Bk                           1
#
#                                                   number_of_reviews  \
# name
# Private room in a clean two bedroom apartment                     0
# Beautiful two bedroom apartment with backyard                   108
# Private bedroom in two bedroom apartment Brooklyn                23
# Sunny, quiet, and cool bedroom in a two bedroom.                  0
# Sweet two bedroom in Crown Heights Bk                             9
#
#                                                   last_review  \
# name
# Private room in a clean two bedroom apartment      No Reviews
# Beautiful two bedroom apartment with backyard      2019-06-20
# Private bedroom in two bedroom apartment Brooklyn  2019-06-03
# Sunny, quiet, and cool bedroom in a two bedroom.   No Reviews
# Sweet two bedroom in Crown Heights Bk              2019-01-21
#
#                                                    reviews_per_month  \
# name
# Private room in a clean two bedroom apartment                   0.00
# Beautiful two bedroom apartment with backyard                   3.12
# Private bedroom in two bedroom apartment Brooklyn               1.58
# Sunny, quiet, and cool bedroom in a two bedroom.                0.00
# Sweet two bedroom in Crown Heights Bk                           0.30
#
#                                                    calculated_host_listings_count  \
# name
# Private room in a clean two bedroom apartment                                   1
# Beautiful two bedroom apartment with backyard                                   2
# Private bedroom in two bedroom apartment Brooklyn                               1
# Sunny, quiet, and cool bedroom in a two bedroom.                                1
# Sweet two bedroom in Crown Heights Bk                                           3
#
#                                                    availability_365
# name
# Private room in a clean two bedroom apartment                  86.0
# Beautiful two bedroom apartment with backyard                 206.0
# Private bedroom in two bedroom apartment Brooklyn             172.0
# Sunny, quiet, and cool bedroom in a two bedroom.               16.0
# Sweet two bedroom in Crown Heights Bk                           0.0
